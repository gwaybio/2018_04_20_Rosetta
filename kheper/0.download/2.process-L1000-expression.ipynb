# %% [markdown]
# # Process LINCS Gene Expression Data into Training and Testing Data
#
# Subset L1000 Gene Expression data to A549 and the Perturbations captured in the Cell Painting Pilot.
# Stratify these profiles we have into 85% training and and 15% testing data.
# The data are balanced across perturbations.

# %%
import os
import numpy as np
import pandas as pd

from cmapPy.pandasGEXpress import parse
from sklearn.model_selection import train_test_split

# %%
np.random.seed(123)

# %%
test_proportion = 0.15

# %%
# Read only the gene names and first plate to save memory
file = os.path.join("data", "GSE92742_Broad_LINCS_Level4_ZSPCINF_mlr12k_n1319138x12328.gctx")
df = parse.parse(file, cidx=[0, 1])

# %%
# Load Genes
gene_file = os.path.join("data", "GSE92742_Broad_LINCS_gene_info.txt.gz")
gene_df = pd.read_csv(gene_file, sep='\t', index_col=0)

landmark_gene_df = gene_df.query("pr_is_lm == 1")
landmark_gene_df.head(2)
# Out:
#            pr_gene_symbol                                pr_gene_title  \
# pr_gene_id
# 780                  DDR1  discoidin domain receptor tyrosine kinase 1
# 7849                 PAX8                                 paired box 8
#
#             pr_is_lm  pr_is_bing
# pr_gene_id
# 780                1           1
# 7849               1           1

# %% [markdown]
# ## Subset L1000 to Landmark Genes

# %%
landmark_indices = list(np.where(df.data_df.index.isin(landmark_gene_df.index.astype(str)))[0])

# %%
df = parse.parse(file, ridx=landmark_indices).data_df

print(df.shape)
df.head(2)
# Out:
# (978, 1319138)
# cid   CPC005_A375_6H_X1_B3_DUO52HI53LO:K06  \
# rid
# 5720                                0.8509
# 466                                 0.0117
#
# cid   CPC005_A375_6H_X2_B3_DUO52HI53LO:K06  \
# rid
# 5720                                0.6964
# 466                                -1.1202
#
# cid   CPC005_A375_6H_X3_B3_DUO52HI53LO:K06  \
# rid
# 5720                                0.7763
# 466                                -1.2383
#
# cid   CPC005_A375_6H_X1_B3_DUO52HI53LO:C19  \
# rid
# 5720                               -0.7216
# 466                                 0.2762
#
# cid   CPC005_A375_6H_X2_B3_DUO52HI53LO:C19  \
# rid
# 5720                               -0.5528
# 466                                -1.9274
#
# cid   CPC005_A375_6H_X3_B3_DUO52HI53LO:C19  \
# rid
# 5720                               -0.8905
# 466                                -1.1556
#
# cid   CPC004_A375_6H_X1_B3_DUO52HI53LO:K13  \
# rid
# 5720                                1.1575
# 466                                 1.6463
#
# cid   CPC004_A375_6H_X2_B3_DUO52HI53LO:K13  \
# rid
# 5720                              -10.4761
# 466                                 2.9997
#
# cid   CPC004_A375_6H_X3_B3_DUO52HI53LO:K13  \
# rid
# 5720                               -0.2220
# 466                                -0.1231
#
# cid   CPC005_A375_6H_X1_B3_DUO52HI53LO:K20  ...  PCLB003_PC3_24H_X3_B13:P15  \
# rid                                         ...
# 5720                               -0.4631  ...                     -2.7870
# 466                                -0.9180  ...                      4.7663
#
# cid   PCLB003_PC3_24H_X3_B13:P16  PCLB003_PC3_24H_X3_B13:P17  \
# rid
# 5720                     -0.9472                     -1.2010
# 466                       4.8015                      1.3907
#
# cid   PCLB003_PC3_24H_X3_B13:P18  PCLB003_PC3_24H_X3_B13:P19  \
# rid
# 5720                      0.1184                      2.1614
# 466                       0.8861                     -2.5416
#
# cid   PCLB003_PC3_24H_X3_B13:P20  PCLB003_PC3_24H_X3_B13:P21  \
# rid
# 5720                      0.4863                     -0.0174
# 466                       4.4342                     -1.2144
#
# cid   PCLB003_PC3_24H_X3_B13:P22  PCLB003_PC3_24H_X3_B13:P23  \
# rid
# 5720                      1.3497                      0.7177
# 466                       4.7777                      0.6917
#
# cid   PCLB003_PC3_24H_X3_B13:P24
# rid
# 5720                      0.6071
# 466                       0.2969
#
# [2 rows x 1319138 columns]

# %% [markdown]
# ## Align with Cell Painting Data

# %%
project_name = "2015_10_05_DrugRepurposing_AravindSubramanian_GolubLab_Broad"
project_dir = os.path.join("~", "bucket", "projects", project_name)

batch_name = "2016_04_01_a549_48hr_batch1"
data_dir = os.path.join(project_dir, "workspace", "backend", batch_name)

# %%
cp_file = os.path.join(data_dir, "{}.csv".format(batch_name))
cp_df = pd.read_csv(cp_file, low_memory=False)

cp_df.loc[cp_df.Metadata_pert_id == "BRD-K60230970", "Metadata_pert_iname"] = "MG-132"
cp_df.loc[cp_df.Metadata_pert_id == "BRD-K50691590", "Metadata_pert_iname"] = "bortezomib"
cp_df.loc[cp_df.Metadata_broad_sample == "DMSO", ["Metadata_pert_iname", "Metadata_pert_id"]] = "DMSO"

print(cp_df.shape)
cp_df.head(2)
# Out:
# (10752, 426)
#     Metadata_broad_sample  Metadata_mmoles_per_liter  \
# 0  BRD-A00147595-001-01-5                   0.041152
# 1  BRD-A00147595-001-01-5                   0.123457
#
#                                        Metadata_moa Metadata_pert_id  \
# 0  insulin sensitizer|PPAR receptor partial agonist    BRD-A00147595
# 1  insulin sensitizer|PPAR receptor partial agonist    BRD-A00147595
#
#    Metadata_pert_id_vendor  Metadata_pert_idose Metadata_pert_iname  \
# 0                      NaN             0.041152       balaglitazone
# 1                      NaN             0.123457       balaglitazone
#
#   Metadata_pert_mfc_desc    Metadata_pert_mfc_id Metadata_pert_vehicle  ...  \
# 0          balaglitazone  BRD-A00147595-001-01-5                  DMSO  ...
# 1          balaglitazone  BRD-A00147595-001-01-5                  DMSO  ...
#
#   Nuclei_Texture_InverseDifferenceMoment_Mito_5_0  \
# 0                                        0.081673
# 1                                        0.335284
#
#   Nuclei_Texture_InverseDifferenceMoment_RNA_10_0  \
# 0                                        0.650381
# 1                                        0.827858
#
#    Nuclei_Texture_InverseDifferenceMoment_RNA_20_0  \
# 0                                         0.804025
# 1                                         0.998955
#
#    Nuclei_Texture_SumAverage_DNA_20_0  Nuclei_Texture_SumAverage_Mito_5_0  \
# 0                           -0.143705                            0.595971
# 1                           -0.621075                            0.773121
#
#    Nuclei_Texture_SumAverage_RNA_20_0  Nuclei_Texture_SumEntropy_DNA_10_0  \
# 0                           -0.874259                            0.058965
# 1                            0.098758                            0.650768
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                          -0.245046                        -0.012409
# 1                           0.303148                         0.588129
#
#    Nuclei_Texture_Variance_RNA_10_0
# 0                         -1.354363
# 1                         -1.264081
#
# [2 rows x 426 columns]

# %%
# Load Experiment data
experiment_file = os.path.join("data", "GSE92742_Broad_LINCS_inst_info.txt.gz")
experiment_df = pd.read_csv(experiment_file, sep='\t', low_memory=False)

print(experiment_df.shape)
experiment_df.head()
# Out:
# (1319138, 11)
#                                  inst_id           rna_plate rna_well pert_id  \
# 0  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:F13  ASG001_MCF7_24H_X1      F13    DMSO
# 1  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:G13  ASG001_MCF7_24H_X1      G13    DMSO
# 2  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:I13  ASG001_MCF7_24H_X1      I13    DMSO
# 3  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:K13  ASG001_MCF7_24H_X1      K13    DMSO
# 4  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:N13  ASG001_MCF7_24H_X1      N13    DMSO
#
#   pert_iname    pert_type  pert_dose pert_dose_unit  pert_time pert_time_unit  \
# 0       DMSO  ctl_vehicle        0.1              %         24              h
# 1       DMSO  ctl_vehicle        0.1              %         24              h
# 2       DMSO  ctl_vehicle        0.1              %         24              h
# 3       DMSO  ctl_vehicle        0.1              %         24              h
# 4       DMSO  ctl_vehicle        0.1              %         24              h
#
#   cell_id
# 0    MCF7
# 1    MCF7
# 2    MCF7
# 3    MCF7
# 4    MCF7

# %% [markdown]
# ## Subset to Perturbations measured in Cell Painting and A549 Profiles

# %%
experiment_sub_df = (
    experiment_df
    .query("pert_id in @cp_df.Metadata_pert_id")
    .query("cell_id == 'A549'")
    .reset_index(drop=True)
)

print(experiment_sub_df.shape)
experiment_sub_df.head(2)
# Out:
# (9326, 11)
#                                  inst_id           rna_plate rna_well  \
# 0  CPC005_A549_24H_X1_B3_DUO52HI53LO:J07  CPC005_A549_24H_X1      J07
# 1  CPC005_A549_24H_X2_B3_DUO52HI53LO:J07  CPC005_A549_24H_X2      J07
#
#          pert_id pert_iname pert_type  pert_dose pert_dose_unit  pert_time  \
# 0  BRD-K53979406   ALX-5407    trt_cp       10.0             um         24
# 1  BRD-K53979406   ALX-5407    trt_cp       10.0             um         24
#
#   pert_time_unit cell_id
# 0              h    A549
# 1              h    A549

# %%
subset_df = (
    df
    .loc[:, experiment_sub_df.inst_id]
    .transpose()
)

print(subset_df.shape)
subset_df.head(2)
# Out:
# (9326, 978)
# rid                                      5720     466    6009    2309     387  \
# cid
# CPC005_A549_24H_X1_B3_DUO52HI53LO:J07  1.2584 -0.1467 -1.1304  0.3373  0.6018
# CPC005_A549_24H_X2_B3_DUO52HI53LO:J07  0.4924  0.9291 -0.1330  0.9097 -0.4239
#
# rid                                      3553     427    5898   23365    6657  \
# cid
# CPC005_A549_24H_X1_B3_DUO52HI53LO:J07  1.3294 -0.8248 -0.1333  0.5331 -0.2269
# CPC005_A549_24H_X2_B3_DUO52HI53LO:J07  0.6745  0.3605  0.7312 -0.8416 -0.4439
#
# rid                                    ...    9738    6793    7358   58472  \
# cid                                    ...
# CPC005_A549_24H_X1_B3_DUO52HI53LO:J07  ...  0.1980 -1.4723  0.4588 -0.0359
# CPC005_A549_24H_X2_B3_DUO52HI53LO:J07  ... -0.8413 -1.0246 -0.2107  0.8534
#
# rid                                     50865   23200   51293   10962   10153  \
# cid
# CPC005_A549_24H_X1_B3_DUO52HI53LO:J07 -0.8057 -0.8344  0.4992  0.9141  0.6025
# CPC005_A549_24H_X2_B3_DUO52HI53LO:J07 -0.4369  0.2388  0.7536  0.2691 -0.4988
#
# rid                                       874
# cid
# CPC005_A549_24H_X1_B3_DUO52HI53LO:J07  0.5556
# CPC005_A549_24H_X2_B3_DUO52HI53LO:J07  0.7143
#
# [2 rows x 978 columns]

# %% [markdown]
# ## Output Training and Testing Data

# %%
train_x, test_x = train_test_split(subset_df, test_size=test_proportion, stratify=experiment_sub_df.pert_id)

# %%
print(train_x.shape)

file = os.path.join("data", "expr_train_data.tsv.gz")
train_x.to_csv(file, sep='\t', index=False)
# Out:
# (7927, 978)

# %%
print(test_x.shape)

file = os.path.join("data", "expr_test_data.tsv.gz")
test_x.to_csv(file, sep='\t', index=False)
# Out:
# (1399, 978)
